# %%
import csv
import json
import regex as regularExpression
import pandas as pd
import numpy as np
import string
import demoji
import emoji
demoji.download_codes()
import re
import nltk
nltk.download('sentiwordnet')
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
from nltk.corpus import sentiwordnet as swn
from nltk.corpus import wordnet as wn
# Out:
# Downloading emoji data ...
# ... OK (Got response in 0.24 seconds)
# Writing emoji data to C:\Users\nandh\.demoji/codes.json ...
# ... OK
# [nltk_data] Downloading package sentiwordnet to
# [nltk_data]     C:\Users\nandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package sentiwordnet is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('punkt')
from nltk import TweetTokenizer
from nltk import pos_tag,pos_tag_sents
#nltk.download('averaged_perceptron_tagger')
#nltk.download()
from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#Reading data into a dataframe
data_read = pd.read_csv('\\Data\\test.csv',encoding='utf-8')
data_test = pd.read_csv('\\Data\\train.csv',encoding='utf-8')

# %%
data_read['Tweets']
# Out:
# 0       hmm <eos> what does your bio mean ? <eos> i do...
# 1         what you like <eos> very little things <eos> ok
# 2            yes <eos> how so ? <eos> i want to fuck babu
# 3           what did you guess <eos> what what <eos> fuck
# 4       we ? <eos> of course we will ! <eos> what gend...
#                               ...
# 5504    not youuu <eos> i also did not not not . <eos>...
# 5505    welcome <eos> why , thank you . <eos> i do not...
# 5506    yes <eos> if only i could afford this <eos> ho...
# 5507    for my information <eos> it is our responsibil...
# 5508    ok . where you work ? <eos> i am off this whol...
# Name: Tweets, Length: 5509, dtype: object

# %%
# List containing short words and its corresponding english words
contractionsDictionary = {
"ain't": "am not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"i'd": "I would",
"i'd've": "I would have",
"i'll": "I will",
"i'll've": "I will have",
"i'm": "I am",
"i've": "I have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so is",
"that'd": "that had",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have",
"thx": "thanks",
"thxs": "thanks",
"r":"are",
"u":"you",
"ur":"your",
"haha":"happy",
"ya":"yes",
"thanx":"thanks",
"plz":"please",
"pls":"please",
"k":"ok"
}

# %%
# funtion to preprocess the given text to remove punctuations, remove html tags, number and conversion of text to lower case
def preprocess(text):
    text=str(text)
    text = text.lower()
    text=text.replace('{html}',"") 
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', text)
    rem_url=re.sub(r'http\S+', '',cleantext)
    clean_data = re.sub('[0-9]+', '', rem_url)
    clean_data = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)","",clean_data)
    clean_data = re.sub("(#[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)","",clean_data)
    return clean_data

# %%
#Applying preprocess function
data_read['clean_Text']=data_read['Tweets'].apply(lambda s:preprocess(s))
data_test['clean_Text']=data_test['Tweets'].apply(lambda s:preprocess(s))

# %%
data_read.iloc[:,0:3]
# Out:
#                                                  Tweets  Polarity  \
# 0     hmm <eos> what does your bio mean ? <eos> i do...         0
# 1       what you like <eos> very little things <eos> ok         0
# 2          yes <eos> how so ? <eos> i want to fuck babu         0
# 3         what did you guess <eos> what what <eos> fuck         0
# 4     we ? <eos> of course we will ! <eos> what gend...         0
# ...                                                 ...       ...
# 5504  not youuu <eos> i also did not not not . <eos>...         0
# 5505  welcome <eos> why , thank you . <eos> i do not...         0
# 5506  yes <eos> if only i could afford this <eos> ho...         0
# 5507  for my information <eos> it is our responsibil...         0
# 5508  ok . where you work ? <eos> i am off this whol...         0
#
#                                              clean_Text
# 0     hmm  what does your bio mean   i dont have any...
# 1                 what you like  very little things  ok
# 2                     yes  how so   i want to fuck babu
# 3                   what did you guess  what what  fuck
# 4     we   of course we will   what gender movies yo...
# ...                                                 ...
# 5504   not youuu  i also did not not not   how to calll
# 5505  welcome  why  thank you   i do not know  you tell
# 5506      yes  if only i could afford this  how are you
# 5507  for my information  it is our responsibility t...
# 5508  ok  where you work   i am off this whole week ...
#
# [5509 rows x 3 columns]

# %%
#Function to tokenize words after preprocessing
def shortToFullText(shorttext):
    ProcessedString = shorttext.copy()
    for txt in ProcessedString:
        if txt in contractionsDictionary.keys():
            loc = ProcessedString.index(txt)
            ProcessedString[loc]=contractionsDictionary[txt]
        continue
    return ProcessedString

# %%
#Function to tokenize words after preprocessing
def tokenize(text):
    tokenizer=TweetTokenizer()
    t_token = tokenizer.tokenize(text)
    return t_token

# %%
#Applying tokenization function
data_read['Tokenized']=data_read['clean_Text'].apply(lambda s:tokenize(s))
data_test['Tokenized']=data_test['clean_Text'].apply(lambda s:tokenize(s))

# %%
data_read.iloc[:,2:4]
# Out:
#                                              clean_Text  \
# 0     hmm  what does your bio mean   i dont have any...
# 1                 what you like  very little things  ok
# 2                     yes  how so   i want to fuck babu
# 3                   what did you guess  what what  fuck
# 4     we   of course we will   what gender movies yo...
# ...                                                 ...
# 5504   not youuu  i also did not not not   how to calll
# 5505  welcome  why  thank you   i do not know  you tell
# 5506      yes  if only i could afford this  how are you
# 5507  for my information  it is our responsibility t...
# 5508  ok  where you work   i am off this whole week ...
#
#                                               Tokenized
# 0     [hmm, what, does, your, bio, mean, i, dont, ha...
# 1           [what, you, like, very, little, things, ok]
# 2               [yes, how, so, i, want, to, fuck, babu]
# 3             [what, did, you, guess, what, what, fuck]
# 4     [we, of, course, we, will, what, gender, movie...
# ...                                                 ...
# 5504  [not, youuu, i, also, did, not, not, not, how,...
# 5505  [welcome, why, thank, you, i, do, not, know, y...
# 5506  [yes, if, only, i, could, afford, this, how, a...
# 5507  [for, my, information, it, is, our, responsibi...
# 5508  [ok, where, you, work, i, am, off, this, whole...
#
# [5509 rows x 2 columns]

# %%
#HappyEmoticons
emoticons_happy = [
    ':-)', ':)', ';)', ':o)', ':]', ':3', ':c)', ':>', '=]', '8)', '=)', ':}',
    ':^)', ':-D', ':D', '8-D', '8D', 'x-D', 'xD', 'X-D', 'XD', '=-D', '=D',
    '=-3', '=3', ':-))', ":'-)", ":')", ':*', ':^*', '>:P', ':-P', ':P', 'X-P',
    'x-p', 'xp', 'XP', ':-p', ':p', '=p', ':-b', ':b', '>:)', '>;)', '>:-)',
    '<3','(:'
    ]

# %%
# Sad Emoticons
emoticons_sad = [
    ':L', ':-/', '>:/', ':S', '>:[', ':@', ':-(', ':[', ':-||', '=L', ':<',
    ':-[', ':-<', '=\\', '=/', '>:(', ':(', '>.<', ":'-(", ":'(", ':\\', ':-c',
    ':c', ':{', '>:\\', ';('
    ]

# %%
# Converting emoji_symbols to text
def emoji_to_text(txts):
    emoji_list=txts.copy()
    for i in emoji_list:
        for j in emoticons_happy:
            re.sub(' +', ' ', i).strip()
            if j == i:
                loc = emoji_list.index(i)
                emoji_list[loc]=":Happy_emoji:"
        continue
        for k in emoticons_sad:
            if k == i:
                location = emoji_list.index(i)
                emoji_list[location]=":Sad_emoji:"
        continue
    return emoji_list

# %%
#Applying emoji_to_text function
data_read['emoji_conversion']=data_read['Tokenized'].apply(lambda s:emoji_to_text(s))
data_test['emoji_conversion']=data_test['Tokenized'].apply(lambda s:emoji_to_text(s))

# %%
data_read.iloc[8:45,3:5]
# Out:
#                                             Tokenized  \
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...
#
#                                      emoji_conversion
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...

# %%
#Converting emoticons to text
def emoticons_to_Text(words):
    convertedlist=words.copy()
    for txt in convertedlist:
        str=emoji.demojize(txt)
        loc = convertedlist.index(txt)
        convertedlist[loc]=str
    return convertedlist

# %%
#Applying emoticon function
data_read['emoji_list']=data_read['emoji_conversion'].apply(lambda s:emoticons_to_Text(s))
data_test['emoji_list']=data_test['emoji_conversion'].apply(lambda s:emoticons_to_Text(s))

# %%
data_read.iloc[8:45,4:6]
# Out:
#                                      emoji_conversion  \
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...
#
#                                            emoji_list
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...

# %%
#denoising
def denoising_characters(words):
    denoise=words.copy()
    spec_chars=[":","?","<",">",".","/","*","#","!","\,","\\","|","\'","\"","[","]","{","}","(",")","+","-","_","&","^","$","%","~","`","@",","," ?"," !"]
    for word in list(spec_chars):
        re.sub(' +', ' ', word).strip()
        re.sub(r'\s([?.!"](?:\s|$))', r'\1', word)
        if ((word in denoise) and (len(word)==1)):
            denoise.remove(word)
    #denoise = [word for word in denoise if word.isalpha()]
    return denoise

# %%
#Applying denoising function
data_read['post_denoise']=data_read['emoji_list'].apply(lambda s:denoising_characters(s))
data_test['post_denoise']=data_test['emoji_list'].apply(lambda s:denoising_characters(s))

# %%
data_read.iloc[8:45,5:7]
# Out:
#                                            emoji_list  \
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...
#
#                                          post_denoise
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...

# %%
# POS tagger function
def posTaggerFunction(texts):
    posConversionList=[]
    for word in texts:
        posConversionList.append(nltk.tag.pos_tag(word_tokenize(word)))  
    return posConversionList

# %%
#Removing stop words
def stop_words(txts):
    to_be_list=txts.copy()
    stop_words=['those', 'they', 'further', 'most', 'or', 'whom', "you'd", 'until', 'shan', 'few', 'in', 'more', 'again', 'against', 'myself', "haven't", 'at', 'where', 'how', 'than', 's', 'are', 'before', 'll', 'wouldn', 'and', 'won', 'your', 'both', 'what', 'an', 'you', 'any', 'd', 'being', 'the', 'out', 'should', 'o', 'own',  "you're", 'had', 'my', 'this', 'to', 'ours', 'then', 'him', 'it', 'off', 'each', 'ain', 'into',  'does', 'because', 'above', 'as', 'ma', 'once', 'having', 'which', 'below', 'by', 'up', 'over','hmm', 'were', "that'll", 'can', 'here', "you've", 'themselves', "mightn't", 'such', 'me', 'through', "should've", 'did', 'on', 'needn', 'their', 'itself', 'am', "hadn't", 'of', 'have', 'we', 'theirs', "hasn't", 'only', 'he', 'm', 're', 'i', 'who', "she's", 'just', 'ourselves', "you'll", 'mightn', 'her', 'been', 'aren', 'with',  'herself', 'y', 'hers', 'do', 'weren', 'yourself', 'so', 've', 'his', 'these', 'mustn', 'a', 'about', 'all', 'yourselves', 'under', 'there', 'same', 'them', 'now', 'will', 'our', 'that',  'some', 'doing', 'but', 'himself', 'when', 'is', 'why', 'for',  'its', 'has',  'other',  "it's", 'yours', 'be', 'was', 'during',  'between', 'she', 'while', 'from', 'if','ur','gf' 'after','!','@','#','"','$','(','.',')','u','r','i']
    for txt in list(to_be_list):
        txt.strip()
        if txt in stop_words:
            to_be_list.remove(txt)
    return to_be_list

# %%
# Applying shortext to full text function
data_read['post_shorttext']=data_read['post_denoise'].apply(lambda s:shortToFullText(s))
data_test['post_shorttext']=data_test['post_denoise'].apply(lambda s:shortToFullText(s))

# %%
data_read.iloc[8:45,6:8]
# Out:
#                                          post_denoise  \
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...
#
#                                        post_shorttext
# 8   [yes, good, advice, best, advice, i, great, th...
# 9   [nice, to, meet, you, hi, nice, to, meet, you,...
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12        [very, nice, thanks, are, you, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24           [sure, will, you, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...

# %%
#Applying stopwords function
data_read['post_Stop']=data_read['post_shorttext'].apply(lambda s:stop_words(s))
data_test['post_Stop']=data_test['post_shorttext'].apply(lambda s:stop_words(s))

# %%
data_read.iloc[8:45,6:9]
# Out:
#                                          post_denoise  \
# 8    [yes, good, advice, best, advice, i, great, thx]
# 9   [nice, to, meet, u, hi, nice, to, meet, you, too]
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12            [very, nice, thanks, r, u, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24             [sure, will, u, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...
#
#                                        post_shorttext  \
# 8   [yes, good, advice, best, advice, i, great, th...
# 9   [nice, to, meet, you, hi, nice, to, meet, you,...
# 10           [yupp, why, do, not, know, i, am, tired]
# 11  [software, software, what, i, plan, on, going,...
# 12        [very, nice, thanks, are, you, know, tamil]
# 13  [first, you, hurt, me, okay, so, i, talked, rude]
# 14  [love, you, you, do, not, recognize, me, i, lo...
# 15  [in, india, fogg, is, going, on, mumbaiindians...
# 16  [is, my, grammar, perfect, or, should, i, need...
# 17                   [by, in, suits, have, good, day]
# 18  [i, dont, know, what, to, write, what, are, yo...
# 19  [so, you, make, jokes, i, already, got, that, ...
# 20  [yeah, mee, too, me, too, all, my, friends, ar...
# 21    [thanks, you, are, welcome, can, you, help, me]
# 22  [offer, you, have, already, enrolled, in, the,...
# 23  [uhhhmm, whyy, not, you, no, im, really, a, ba...
# 24           [sure, will, you, cal, me, ni, ok, then]
# 25  [about, what, i, just, told, i, should, you, d...
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [now, do, not, give, me, a, chance, to, be, an...
# 28  [watch, spitsvilla, at, p, m, today, both, are...
# 29  [uuu, no, in, not, what, is, wrong, with, you,...
# 30  [but, you, do, i, cannot, want, any, of, this,...
# 31  [ok, hey, you, do, not, belong, here, i, belon...
# 32  [purple, purple, means, i, am, in, love, me, too]
# 33  [you, wont, get, it, i, will, not, actually, y...
# 34         [thn, tell, me, just, did, who, is, priya]
# 35  [why, alright, i, do, not, go, out, with, peop...
# 36  [do, you, like, video, games, hmm, yes, have, ...
# 37  [buy, oh, you, are, buying, me, a, car, okays,...
# 38  [just, asking, you, just, spelled, it, do, not...
# 39  [not, possible, very, possible, prepare, for, ...
# 40  [your, photo, please, no, pics, clicked, sigh,...
# 41        [oh, sorry, meh, it, is, ok, i, talk, fast]
# 42  [what, is, press, box, turtle, itself, inside,...
# 43  [so, what, all, i, needed, to, know, what, you...
# 44  [i, already, heard, of, ir, that, proves, a, l...
#
#                                             post_Stop
# 8    [yes, good, advice, best, advice, great, thanks]
# 9                   [nice, meet, hi, nice, meet, too]
# 10                           [yupp, not, know, tired]
# 11  [software, software, plan, going, development,...
# 12                  [very, nice, thanks, know, tamil]
# 13                  [first, hurt, okay, talked, rude]
# 14                       [love, not, recognize, love]
# 15  [india, fogg, going, mumbaiindians, getting, r...
# 16  [grammar, perfect, need, learn, yes, possible,...
# 17                                 [suits, good, day]
# 18  [dont, know, write, writing, profile, picture,...
# 19  [make, jokes, already, got, good, joke, laughe...
# 20  [yeah, mee, too, too, friends, also, excited, ...
# 21                            [thanks, welcome, help]
# 22  [offer, already, enrolled, offer, error, pleas...
# 23    [uhhhmm, whyy, not, no, im, really, bad, bitch]
# 24                                [sure, cal, ni, ok]
# 25                                      [told, drunk]
# 26  [yeaaa, black, panther, black, panther, teaser...
# 27  [not, give, chance, danger, evil, not, give, c...
# 28  [watch, spitsvilla, p, today, tough, matches, ...
# 29                   [uuu, no, not, wrong, hate, uuu]
# 30  [cannot, want, never, doubt, happy, im, bored,...
# 31                     [ok, hey, not, belong, belong]
# 32                 [purple, purple, means, love, too]
# 33                   [wont, get, not, actually, wont]
# 34                                 [thn, tell, priya]
# 35       [alright, not, go, people, not, know, lives]
# 36          [like, video, games, yes, played, skyrim]
# 37           [buy, oh, buying, car, okays, see, soon]
# 38                      [asking, spelled, not, watch]
# 39  [not, possible, very, possible, prepare, tears...
# 40     [photo, please, no, pics, clicked, sigh, love]
# 41                   [oh, sorry, meh, ok, talk, fast]
# 42           [press, box, turtle, inside, box, means]
# 43                        [needed, know, need, knows]
# 44                  [already, heard, ir, proves, lot]

# %%
#Removing emoticons seperately
def emojisepearation(sentence):
    to_be_extracted=sentence.copy()
    for text in to_be_extracted:
        #to_be_extracted=(re.match(r':a-zA-Z:'),text)
        filtered = filter(re.match(r':\w+:'), text) 
    if filtered!=0:
        return filtered
    else: 
        return None

# %%
#Applying posTagger function
data_read['post_posConversion']=data_read['post_Stop'].apply(lambda s:posTaggerFunction(s))

# %%
data_read['post_posConversion']
# Out:
# 0       [[(bio, NN)], [(mean, NN)], [(dont, NN)], [(bi...
# 1       [[(like, IN)], [(very, RB)], [(little, JJ)], [...
# 2       [[(yes, NNS)], [(want, NN)], [(fuck, NN)], [(b...
# 3                           [[(guess, NN)], [(fuck, NN)]]
# 4       [[(course, NN)], [(gender, NN)], [(movies, NNS...
#                               ...
# 5504    [[(not, RB)], [(youuu, NN)], [(also, RB)], [(n...
# 5505    [[(welcome, NN)], [(thank, NN)], [(not, RB)], ...
# 5506        [[(yes, NNS)], [(could, MD)], [(afford, NN)]]
# 5507    [[(information, NN)], [(responsibility, NN)], ...
# 5508    [[(ok, NN)], [(work, NN)], [(whole, JJ)], [(we...
# Name: post_posConversion, Length: 5509, dtype: object

# %%
# function to count the occurence of words
#global word_frequency
word_frequency={}
def frequent_occuringWords(words):
    for element in words:
        if element in word_frequency:
            word_frequency[element] = word_frequency[element] + 1
        else:
            word_frequency[element] = 1

# %%
#Applying frequent_occuringWords function
data_read['post_Stop'].apply(lambda s:frequent_occuringWords(s))
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 5504    None
# 5505    None
# 5506    None
# 5507    None
# 5508    None
# Name: post_Stop, Length: 5509, dtype: object

# %%
#sorting the frequently occuring words
from collections import OrderedDict
frequent_words = sorted(word_frequency.items(), key=lambda kv: kv[1], reverse=True)
print(frequent_words)
# Out:
# [('not', 1550), ('know', 651), ('yes', 553), ('no', 531), ('ok', 525), ('like', 451), ('good', 376), ('love', 366), ('want', 322), ('tell', 320), ('one', 245), ('go', 217), ('too', 214), ('yeah', 211), ('send', 210), ('please', 205), ('happy', 192), ('really', 188), ('thanks', 187), ('get', 186), ('think', 175), ('see', 173), ('nothing', 157), ('oh', 156), ('say', 156), ('well', 152), ('very', 146), ('talk', 144), ('cannot', 140), ('cool', 139), ('okay', 138), ('need', 137), ('thank', 137), ('sorry', 137), ('time', 136), ('give', 135), ('would', 133), ('something', 125), ('ask', 121), ('mean', 115), ('name', 115), ('come', 114), ('sure', 113), ('much', 110), ('going', 106), ('fine', 104), ('im', 101), ('right', 101), ('friend', 99), ('never', 98), ('talking', 98), ('make', 96), ('movie', 96), ('day', 94), ('p', 94), ('pic', 94), ('welcome', 90), ('lol', 90), ('nice', 89), ('life', 89), ('funny', 87), ('best', 85), ('always', 81), ('got', 80), ('work', 79), ('let', 79), ('back', 79), ('said', 78), ('help', 77), ('bad', 77), ('even', 77), ('call', 76), ('number', 75), ('better', 74), ('bye', 73), ('understand', 73), ('fuck', 71), ('girl', 71), ('home', 70), ('hey', 70), ('sleep', 70), ('way', 70), ('meet', 69), ('hate', 69), ('question', 69), ('friends', 68), ('people', 67), ('wanna', 67), ('fun', 66), ('thing', 66), ('anything', 66), ('also', 65), ('today', 65), ('feel', 64), ('first', 63), ('great', 62), ('try', 60), ('baby', 59), ('take', 59), ('could', 57), ('asking', 56), ('us', 56), ('night', 56), ('answer', 56), ('person', 56), ('stop', 55), ('someone', 55), ('everything', 54), ('many', 54), ('still', 54), ('new', 54), ('already', 53), ('chat', 53), ('english', 53), ('find', 52), ('sad', 52), ('pretty', 52), ('things', 51), ('guess', 49), ('watch', 49), ('means', 49), ('thats', 49), ('nope', 48), ('dear', 47), ('actually', 46), ('may', 46), ('joke', 45), ('play', 45), ('stupid', 45), ('lot', 44), ('leave', 43), ('real', 43), ('ever', 43), ('year', 42), ('human', 42), ('thought', 42), ('done', 42), ('live', 42), ('eat', 42), ('wait', 41), ('mind', 41), ('maybe', 41), ('next', 40), ('whats', 40), ('reply', 40), ('look', 40), ('photo', 39), ('phone', 39), ('course', 38), ('hell', 38), ('ohh', 38), ('awesome', 38), ('show', 38), ('wrong', 38), ('wow', 38), ('song', 38), ('money', 38), ('language', 38), ('girlfriend', 38), ('n', 38), ('picture', 37), ('though', 37), ('another', 36), ('problem', 36), ('sent', 36), ('sex', 36), ('yet', 36), ('game', 36), ('made', 36), ('busy', 36), ('job', 36), ('boring', 35), ('enough', 35), ('yup', 35), ('man', 35), ('hope', 35), ('alone', 35), ('old', 35), ('start', 34), ('long', 34), ('happened', 34), ('saying', 34), ('miss', 33), ('wish', 33), ('boy', 33), ('lets', 33), ('tomorrow', 33), ('place', 32), ('kind', 32), ('use', 32), ('change', 32), ('rude', 31), ('every', 31), ('last', 31), ('true', 31), ('waiting', 31), ('little', 30), ('india', 30), ('getting', 30), ('read', 30), ('told', 30), ('believe', 30), ('lost', 30), ('face', 30), ('later', 30), ('else', 30), ('keep', 30), ('cant', 30), ('ai', 30), ('listen', 30), ('food', 30), ('speak', 29), ('robot', 29), ('trying', 29), ('dude', 29), ('guy', 29), ('type', 29), ('video', 28), ('explain', 28), ('morning', 28), ('bed', 28), ('gf', 28), ('chatting', 28), ('gonna', 28), ('soon', 27), ('thinking', 27), ('age', 27), ('makes', 27), ('bot', 27), ('free', 27), ('after', 27), ('study', 26), ('house', 26), ('care', 26), ('feeling', 26), ('working', 26), ('wht', 25), ('angry', 25), ('teach', 25), ('wt', 25), ('stay', 25), ('kidding', 25), ('google', 25), ('remember', 25), ('movies', 24), ('hurt', 24), ('hard', 24), ('fast', 24), ('favorite', 24), ('seriously', 24), ('girls', 24), ('everyone', 24), ('sweet', 24), ('asked', 24), ('message', 24), ('perfect', 23), ('learn', 23), ('topic', 23), ('hahaha', 23), ('sense', 23), ('c', 23), ('wat', 23), ('looking', 23), ('beautiful', 23), ('room', 23), ('yea', 23), ('exactly', 23), ('down', 23), ('point', ...

# %%
#Feature Exctraction extracting 100 frequently occuring words
result_list =[x[0] for x in frequent_words]
toplist=result_list[:500]
print(toplist)
# Out:
# ['not', 'know', 'yes', 'no', 'ok', 'like', 'good', 'love', 'want', 'tell', 'one', 'go', 'too', 'yeah', 'send', 'please', 'happy', 'really', 'thanks', 'get', 'think', 'see', 'nothing', 'oh', 'say', 'well', 'very', 'talk', 'cannot', 'cool', 'okay', 'need', 'thank', 'sorry', 'time', 'give', 'would', 'something', 'ask', 'mean', 'name', 'come', 'sure', 'much', 'going', 'fine', 'im', 'right', 'friend', 'never', 'talking', 'make', 'movie', 'day', 'p', 'pic', 'welcome', 'lol', 'nice', 'life', 'funny', 'best', 'always', 'got', 'work', 'let', 'back', 'said', 'help', 'bad', 'even', 'call', 'number', 'better', 'bye', 'understand', 'fuck', 'girl', 'home', 'hey', 'sleep', 'way', 'meet', 'hate', 'question', 'friends', 'people', 'wanna', 'fun', 'thing', 'anything', 'also', 'today', 'feel', 'first', 'great', 'try', 'baby', 'take', 'could', 'asking', 'us', 'night', 'answer', 'person', 'stop', 'someone', 'everything', 'many', 'still', 'new', 'already', 'chat', 'english', 'find', 'sad', 'pretty', 'things', 'guess', 'watch', 'means', 'thats', 'nope', 'dear', 'actually', 'may', 'joke', 'play', 'stupid', 'lot', 'leave', 'real', 'ever', 'year', 'human', 'thought', 'done', 'live', 'eat', 'wait', 'mind', 'maybe', 'next', 'whats', 'reply', 'look', 'photo', 'phone', 'course', 'hell', 'ohh', 'awesome', 'show', 'wrong', 'wow', 'song', 'money', 'language', 'girlfriend', 'n', 'picture', 'though', 'another', 'problem', 'sent', 'sex', 'yet', 'game', 'made', 'busy', 'job', 'boring', 'enough', 'yup', 'man', 'hope', 'alone', 'old', 'start', 'long', 'happened', 'saying', 'miss', 'wish', 'boy', 'lets', 'tomorrow', 'place', 'kind', 'use', 'change', 'rude', 'every', 'last', 'true', 'waiting', 'little', 'india', 'getting', 'read', 'told', 'believe', 'lost', 'face', 'later', 'else', 'keep', 'cant', 'ai', 'listen', 'food', 'speak', 'robot', 'trying', 'dude', 'guy', 'type', 'video', 'explain', 'morning', 'bed', 'gf', 'chatting', 'gonna', 'soon', 'thinking', 'age', 'makes', 'bot', 'free', 'after', 'study', 'house', 'care', 'feeling', 'working', 'wht', 'angry', 'teach', 'wt', 'stay', 'kidding', 'google', 'remember', 'movies', 'hurt', 'hard', 'fast', 'favorite', 'seriously', 'girls', 'everyone', 'sweet', 'asked', 'message', 'perfect', 'learn', 'topic', 'hahaha', 'sense', 'c', 'wat', 'looking', 'beautiful', 'room', 'yea', 'exactly', 'down', 'point', 'plan', 'iam', 'chocolate', 'mine', 'college', 'na', 'cute', 'date', 'shall', 'office', 'questions', 'world', 'serious', 'coming', 'ohhh', 'tonight', 'days', 'hear', 'dinner', 'special', 'exams', 'stuff', 'xd', 'aww', 'smart', 'mood', 'interesting', 'truth', 'watching', 'years', 'full', 'called', 'lie', 'ha', 'wanted', 'music', 'share', 'crazy', 'software', 'bored', 'away', 'different', 'marry', 'shut', 'joking', 'seen', 'words', 'dream', 'wear', 'meant', 'online', 'move', 'glad', 'anyone', 'songs', 'idea', 'book', 'hello', 'single', 'cause', 'party', 'knew', 'uh', 'agree', 'x', 'nd', 'kiss', 'bit', 'yep', 'without', 'sing', 'heart', 'matter', 'part', 'country', 'must', 'forget', 'interested', 'anymore', 'birthday', 'hi', 'alright', 'plans', 'amazing', 'using', 'photos', 'hm', 'confused', 'happen', 'favourite', 'check', 'intelligent', 'soo', 'times', 'big', 'quite', 'story', 'knw', 'relationship', 'lucky', 'end', 'bf', 'indian', 'god', 'laughing', 'wont', 'sleepy', 'suggest', 'youre', 'definitely', 'ah', 'sleeping', 'least', 'around', 'damn', 'left', 'gift', 'future', 'dumb', 'boyfriend', 'bro', 'dont', 'tired', 'possible', 'games', 'heard', 'v', 'text', 'abt', 'th', 'ill', 'ohk', 'eyes', 'dp', 'ready', 'watched', 'word', 'forgot', 'school', 'mom', 'link', 'intelligence', 'milk', 'case', 'reason', 'meaning', 'dead', 'late', 'okk', 'loves', 'saw', 'lunch', 'yaar', 'studying', 'romantic', 'family', 'write', 'buy', 'pics', 'hours', 'line', 'huh', 'anyway', 'annoying', 'um', 'parents', 'sexy', 'computer', 'indeed', 'beach', 'mobile', 'week', 'together', 'month', 'friendship', 'ahead', 'tv', 'supposed', 'b', 'beauty', 'jokes', 'anyway ...

# %%
russel_complex_list=['alarmed','tense','afraid','angry','annoyed','distressed','frustrated','aroused','astonished','excited','delighted','happy','pleased','glad','serene','content','atease','satisfied','relaxed','calm','miserable','sad','gloomy','depressed','bored','droopy','tired']

# %%
#Extracted Knowledge Base
seedlist=list(toplist) 
seedlist.extend(element for element in russel_complex_list if element not in seedlist) 
print(seedlist)
# Out:
# ['not', 'know', 'yes', 'no', 'ok', 'like', 'good', 'love', 'want', 'tell', 'one', 'go', 'too', 'yeah', 'send', 'please', 'happy', 'really', 'thanks', 'get', 'think', 'see', 'nothing', 'oh', 'say', 'well', 'very', 'talk', 'cannot', 'cool', 'okay', 'need', 'thank', 'sorry', 'time', 'give', 'would', 'something', 'ask', 'mean', 'name', 'come', 'sure', 'much', 'going', 'fine', 'im', 'right', 'friend', 'never', 'talking', 'make', 'movie', 'day', 'p', 'pic', 'welcome', 'lol', 'nice', 'life', 'funny', 'best', 'always', 'got', 'work', 'let', 'back', 'said', 'help', 'bad', 'even', 'call', 'number', 'better', 'bye', 'understand', 'fuck', 'girl', 'home', 'hey', 'sleep', 'way', 'meet', 'hate', 'question', 'friends', 'people', 'wanna', 'fun', 'thing', 'anything', 'also', 'today', 'feel', 'first', 'great', 'try', 'baby', 'take', 'could', 'asking', 'us', 'night', 'answer', 'person', 'stop', 'someone', 'everything', 'many', 'still', 'new', 'already', 'chat', 'english', 'find', 'sad', 'pretty', 'things', 'guess', 'watch', 'means', 'thats', 'nope', 'dear', 'actually', 'may', 'joke', 'play', 'stupid', 'lot', 'leave', 'real', 'ever', 'year', 'human', 'thought', 'done', 'live', 'eat', 'wait', 'mind', 'maybe', 'next', 'whats', 'reply', 'look', 'photo', 'phone', 'course', 'hell', 'ohh', 'awesome', 'show', 'wrong', 'wow', 'song', 'money', 'language', 'girlfriend', 'n', 'picture', 'though', 'another', 'problem', 'sent', 'sex', 'yet', 'game', 'made', 'busy', 'job', 'boring', 'enough', 'yup', 'man', 'hope', 'alone', 'old', 'start', 'long', 'happened', 'saying', 'miss', 'wish', 'boy', 'lets', 'tomorrow', 'place', 'kind', 'use', 'change', 'rude', 'every', 'last', 'true', 'waiting', 'little', 'india', 'getting', 'read', 'told', 'believe', 'lost', 'face', 'later', 'else', 'keep', 'cant', 'ai', 'listen', 'food', 'speak', 'robot', 'trying', 'dude', 'guy', 'type', 'video', 'explain', 'morning', 'bed', 'gf', 'chatting', 'gonna', 'soon', 'thinking', 'age', 'makes', 'bot', 'free', 'after', 'study', 'house', 'care', 'feeling', 'working', 'wht', 'angry', 'teach', 'wt', 'stay', 'kidding', 'google', 'remember', 'movies', 'hurt', 'hard', 'fast', 'favorite', 'seriously', 'girls', 'everyone', 'sweet', 'asked', 'message', 'perfect', 'learn', 'topic', 'hahaha', 'sense', 'c', 'wat', 'looking', 'beautiful', 'room', 'yea', 'exactly', 'down', 'point', 'plan', 'iam', 'chocolate', 'mine', 'college', 'na', 'cute', 'date', 'shall', 'office', 'questions', 'world', 'serious', 'coming', 'ohhh', 'tonight', 'days', 'hear', 'dinner', 'special', 'exams', 'stuff', 'xd', 'aww', 'smart', 'mood', 'interesting', 'truth', 'watching', 'years', 'full', 'called', 'lie', 'ha', 'wanted', 'music', 'share', 'crazy', 'software', 'bored', 'away', 'different', 'marry', 'shut', 'joking', 'seen', 'words', 'dream', 'wear', 'meant', 'online', 'move', 'glad', 'anyone', 'songs', 'idea', 'book', 'hello', 'single', 'cause', 'party', 'knew', 'uh', 'agree', 'x', 'nd', 'kiss', 'bit', 'yep', 'without', 'sing', 'heart', 'matter', 'part', 'country', 'must', 'forget', 'interested', 'anymore', 'birthday', 'hi', 'alright', 'plans', 'amazing', 'using', 'photos', 'hm', 'confused', 'happen', 'favourite', 'check', 'intelligent', 'soo', 'times', 'big', 'quite', 'story', 'knw', 'relationship', 'lucky', 'end', 'bf', 'indian', 'god', 'laughing', 'wont', 'sleepy', 'suggest', 'youre', 'definitely', 'ah', 'sleeping', 'least', 'around', 'damn', 'left', 'gift', 'future', 'dumb', 'boyfriend', 'bro', 'dont', 'tired', 'possible', 'games', 'heard', 'v', 'text', 'abt', 'th', 'ill', 'ohk', 'eyes', 'dp', 'ready', 'watched', 'word', 'forgot', 'school', 'mom', 'link', 'intelligence', 'milk', 'case', 'reason', 'meaning', 'dead', 'late', 'okk', 'loves', 'saw', 'lunch', 'yaar', 'studying', 'romantic', 'family', 'write', 'buy', 'pics', 'hours', 'line', 'huh', 'anyway', 'annoying', 'um', 'parents', 'sexy', 'computer', 'indeed', 'beach', 'mobile', 'week', 'together', 'month', 'friendship', 'ahead', 'tv', 'supposed', 'b', 'beauty', 'jokes', 'anyway ...

# %%
def tag_conversion(to_be_convertedtag):
    if to_be_convertedtag.startswith('J'):
        return wn.ADJ
    elif to_be_convertedtag.startswith('N'):
        return wn.NOUN
    elif to_be_convertedtag.startswith('R'):
        return wn.ADV
    elif to_be_convertedtag.startswith('V'):
        return wn.VERB
    return None

# %%
from nltk.corpus import wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.corpus import sentiwordnet as swn
seedlist_Classification={}
def word_classification(frequent_list):
    for word in frequent_list:
        words = word_tokenize(word)
        tags = pos_tag(words)
        wn_tag = tag_conversion(tags[0][1])
        word = tags[0][0]
        lemmatizer = WordNetLemmatizer()
        lemma = lemmatizer.lemmatize(word)
        if not lemma:
            continue
        synsets = wn.synsets(lemma, pos=wn_tag)
      #  print(synsets)
        if not synsets:
            continue
        synset = synsets[0]
        swn_synset = swn.senti_synset(synset.name())
        positive_score= float(swn_synset.pos_score())
        negative_score= float(swn_synset.neg_score())
        if(positive_score > negative_score):
            if(positive_score >= 0.5 and positive_score < 1 ):
                seedlist_Classification[word]="Happy-Active Class"
            elif(positive_score >= 0.1 and positive_score < 0.5 ):
                seedlist_Classification[word]="Happy-Inactive Class"
        elif (positive_score < negative_score):
            if(negative_score >= 0.5 and negative_score < 1 ):
                seedlist_Classification[word]="Unhappy-Active Class"
            elif(negative_score >= 0.1 and negative_score < 0.5 ):
                seedlist_Classification[word]="Unhappy-Inactive Class"
        elif (positive_score == negative_score):
            continue

# %%
word_classification(seedlist)

# %%
print(seedlist_Classification)
# Out:
# {'not': 'Unhappy-Active Class', 'yes': 'Happy-Inactive Class', 'no': 'Unhappy-Inactive Class', 'like': 'Happy-Inactive Class', 'good': 'Happy-Active Class', 'love': 'Happy-Active Class', 'want': 'Unhappy-Inactive Class', 'too': 'Unhappy-Inactive Class', 'happy': 'Happy-Active Class', 'really': 'Happy-Active Class', 'thanks': 'Happy-Inactive Class', 'get': 'Happy-Inactive Class', 'well': 'Happy-Inactive Class', 'talk': 'Unhappy-Inactive Class', 'cool': 'Unhappy-Inactive Class', 'give': 'Unhappy-Inactive Class', 'fine': 'Unhappy-Inactive Class', 'friend': 'Happy-Inactive Class', 'never': 'Unhappy-Active Class', 'welcome': 'Happy-Inactive Class', 'nice': 'Happy-Active Class', 'best': 'Happy-Active Class', 'got': 'Happy-Inactive Class', 'help': 'Happy-Active Class', 'bad': 'Unhappy-Active Class', 'even': 'Happy-Inactive Class', 'number': 'Unhappy-Inactive Class', 'better': 'Happy-Active Class', 'hate': 'Unhappy-Inactive Class', 'question': 'Unhappy-Inactive Class', 'friends': 'Happy-Inactive Class', 'fun': 'Happy-Inactive Class', 'today': 'Happy-Inactive Class', 'feel': 'Happy-Inactive Class', 'still': 'Unhappy-Inactive Class', 'new': 'Happy-Inactive Class', 'already': 'Happy-Inactive Class', 'chat': 'Unhappy-Inactive Class', 'pretty': 'Unhappy-Inactive Class', 'guess': 'Unhappy-Inactive Class', 'dear': 'Happy-Inactive Class', 'actually': 'Happy-Inactive Class', 'joke': 'Happy-Inactive Class', 'stupid': 'Unhappy-Active Class', 'thought': 'Happy-Inactive Class', 'mind': 'Happy-Inactive Class', 'hell': 'Unhappy-Inactive Class', 'wrong': 'Unhappy-Active Class', 'wow': 'Unhappy-Inactive Class', 'another': 'Unhappy-Inactive Class', 'problem': 'Unhappy-Active Class', 'yet': 'Happy-Inactive Class', 'busy': 'Happy-Inactive Class', 'enough': 'Happy-Inactive Class', 'hope': 'Happy-Inactive Class', 'old': 'Happy-Inactive Class', 'wish': 'Happy-Active Class', 'boy': 'Happy-Inactive Class', 'last': 'Unhappy-Inactive Class', 'true': 'Happy-Active Class', 'little': 'Unhappy-Inactive Class', 'getting': 'Happy-Inactive Class', 'read': 'Happy-Inactive Class', 'believe': 'Happy-Inactive Class', 'lost': 'Unhappy-Active Class', 'chatting': 'Happy-Inactive Class', 'soon': 'Unhappy-Inactive Class', 'free': 'Happy-Inactive Class', 'feeling': 'Unhappy-Inactive Class', 'kidding': 'Unhappy-Inactive Class', 'hurt': 'Unhappy-Active Class', 'hard': 'Unhappy-Active Class', 'favorite': 'Happy-Inactive Class', 'seriously': 'Happy-Inactive Class', 'sense': 'Happy-Inactive Class', 'yea': 'Happy-Inactive Class', 'exactly': 'Happy-Inactive Class', 'down': 'Unhappy-Inactive Class', 'date': 'Happy-Inactive Class', 'questions': 'Unhappy-Inactive Class', 'serious': 'Happy-Inactive Class', 'smart': 'Unhappy-Active Class', 'interesting': 'Happy-Inactive Class', 'truth': 'Happy-Active Class', 'watching': 'Happy-Inactive Class', 'called': 'Happy-Inactive Class', 'wanted': 'Happy-Inactive Class', 'crazy': 'Unhappy-Inactive Class', 'bored': 'Happy-Inactive Class', 'different': 'Happy-Active Class', 'wear': 'Unhappy-Inactive Class', 'idea': 'Happy-Inactive Class', 'bit': 'Unhappy-Inactive Class', 'heart': 'Unhappy-Inactive Class', 'matter': 'Unhappy-Inactive Class', 'must': 'Happy-Inactive Class', 'interested': 'Happy-Active Class', 'amazing': 'Unhappy-Inactive Class', 'favourite': 'Happy-Inactive Class', 'big': 'Happy-Inactive Class', 'quite': 'Unhappy-Active Class', 'lucky': 'Happy-Active Class', 'definitely': 'Happy-Inactive Class', 'sleeping': 'Unhappy-Inactive Class', 'gift': 'Happy-Inactive Class', 'possible': 'Happy-Active Class', 'ill': 'Unhappy-Active Class', 'watched': 'Happy-Inactive Class', 'mom': 'Happy-Active Class', 'intelligence': 'Happy-Active Class', 'dead': 'Unhappy-Active Class', 'late': 'Unhappy-Inactive Class', 'loves': 'Happy-Active Class', 'friendship': 'Happy-Inactive Class', 'beauty': 'Happy-Active Class', 'jokes': 'Happy-Inactive Class', 'worst': 'Unhappy-Active Class', 'obviously': 'Happy-Active Class', 'idiot': 'Unhappy-Inactive Class', 'loved': 'Ha ...

# %%
#rule-based classification
def ruleBasedClassification(tagged_words):
    taglist=[]
    classified_class_count={}
    for txt in tagged_words:
        for word, tag in txt:
            tuplelist=[]            
            if word in seedlist_Classification.keys():
                classified_class=seedlist_Classification[word]
                if classified_class in classified_class_count:
                    classified_class_count[classified_class] = classified_class_count[classified_class] + 1
                else:
                    classified_class_count[classified_class] = 1
            continue
    if classified_class_count:
        MaxValue = max(classified_class_count.items(), key=lambda x: x[1]) 
        listclassification = list()
        # Iterate over all the items in dictionary to find keys with max value
        for key, value in classified_class_count.items():
            if value == MaxValue[1]:
                listclassification.append(key)
        if len(listclassification)==4:
            max_Classified="Happy-Active Class"  
        elif len(listclassification)==2 or len(listclassification)==3:
            res = [i for i in listclassification if "Unhappy" in i]
            if(len(res)>(len(listclassification)-len(res))):
                max_Classified="Unhappy-Active Class"               
            elif((len(listclassification)-len(res))>len(res)):
                max_Classified="Happy-Inactive Class"
            elif((len(listclassification)-len(res))==len(res)):
                max_Classified="Happy-Active Class"               
        else:
            max_Classified=listclassification
    else:
        max_Classified="neutral"
    return max_Classified

# %%
data_read['classified']=data_read['post_posConversion'].apply(lambda s:ruleBasedClassification(s))

# %%
data_read['classified']
# Out:
# 0                        neutral
# 1             Happy-Active Class
# 2             Happy-Active Class
# 3       [Unhappy-Inactive Class]
# 4         [Happy-Inactive Class]
#                   ...
# 5504      [Unhappy-Active Class]
# 5505          Happy-Active Class
# 5506      [Happy-Inactive Class]
# 5507                     neutral
# 5508      [Happy-Inactive Class]
# Name: classified, Length: 5509, dtype: object

# %%
X = data_read['Tweets']
y = data_read['Polarity']
test = data_test['Tweets']

# %%
train_tweets = data_read[['Polarity','Tweets']]
test = data_test['Tweets']

# %%
def text_processing(tweet):
    
    #Generating the list of words in the tweet (hastags and other punctuations removed)
    def form_sentence(tweet):
        tweet_blob = TextBlob(tweet)
        return ' '.join(tweet_blob.words)
    new_tweet = form_sentence(tweet)
    
    #Removing stopwords and words with unusual symbols
    def no_user_alpha(tweet):
        tweet_list = [ele for ele in tweet.split() if ele != 'user']
        clean_tokens = [t for t in tweet_list if re.match(r'[^\W\d]*$', t)]
        clean_s = ' '.join(clean_tokens)
        clean_mess = [word for word in clean_s.split() if word.lower() not in stopwords.words('english')]
        return clean_mess
    no_punc_tweet = no_user_alpha(new_tweet)
    
    #Normalizing the words in tweets 
    def normalization(tweet_list):
        lem = WordNetLemmatizer()
        normalized_tweet = []
        for word in tweet_list:
            normalized_text = lem.lemmatize(word,'v')
            normalized_tweet.append(normalized_text)
        return normalized_tweet
    
    
    return normalization(no_punc_tweet)

# %%
#Machine Learning Pipeline
pipeline = Pipeline([
    ('bow',CountVectorizer(analyzer=text_processing)),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  
])
pipeline.fit(msg_train,label_train)
# Out:
# Pipeline(memory=None,
#          steps=[('bow',
#                  CountVectorizer(analyzer=<function text_processing at 0x0000024468790B88>,
#                                  binary=False, decode_error='strict',
#                                  dtype=<class 'numpy.int64'>, encoding='utf-8',
#                                  input='content', lowercase=True, max_df=1.0,
#                                  max_features=None, min_df=1,
#                                  ngram_range=(1, 1), preprocessor=None,
#                                  stop_words=None, strip_accents=None,
#                                  token_pattern='(?u)\\b\\w\\w+\\b',
#                                  tokenizer=None, vocabulary=None)),
#                 ('tfidf',
#                  TfidfTransformer(norm='l2', smooth_idf=True,
#                                   sublinear_tf=False, use_idf=True)),
#                 ('classifier',
#                  MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True))],
#          verbose=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from textblob import TextBlob
from nltk.corpus import stopwords
msg_train, msg_test, label_train, label_test = train_test_split(train_tweets['Tweets'], train_tweets['Polarity'], test_size=0.2)

# %%
predictions = pipeline.predict(msg_test)
print("KFold CrossValidation Results")
print(classification_report(predictions,label_test))
print ('\n')
print("Overall Accuracy:")
print(accuracy_score(predictions,label_test))
# Out:
# KFold CrossValidation Results
#               precision    recall  f1-score   support
#
#            0       1.00      0.85      0.92      1102
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         0
#
#     accuracy                           0.85      1102
#    macro avg       0.25      0.21      0.23      1102
# weighted avg       1.00      0.85      0.92      1102
#
#
#
# Overall Accuracy:
# 0.8475499092558983
# C:\Users\nandh\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1439: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
